# %%
# Variables
x = 3
print(x)

y = 3.14
print(y)

z = "Mama"
print(z)

isOxfordTheBest = False
isCambridgeTheBest = True
print(isOxfordTheBest)
print(isCambridgeTheBest)
# Out:
# 3
# 3.14
# Mama
# False
# True

# %%
# Arithmetic operators
x = 3
y = 2
# Addition
print(x + y)
# Subtraction
print(x - y)
# Multiplication
print(x * y)
# Division
print(x / y)
# Floor division
print(x // y)
# Reminder
print(x % y)
# Raise to the power
print(x ** y)
# Out:
# 5
# 1
# 6
# 1.5
# 1
# 1
# 9

# %%
# Assign and add
x = 3
#// x = x +3
x += 3
print(x)

# Assign and subtract
x = 3
# x = x - 3
x -= 3
print(x)

# Assign and multiply
x = 3
# x = x * 2
x *= 2
print(x)

# Assign and divide
x = 3
# x = x / 3
x /= 3
print(x)

# Assign and divide
x = 4
# x = x // 3
x //= 3
print(x)

# Assign and reminder
x = 4
x %= 3
print(x)

# Assign and raise to the power
x = 3
x **= 3
print(x)
# Out:
# 6
# 0
# 6
# 1.0
# 1
# 1
# 27

# %%
# Strings
x = "Mom"
y = "Dad"
z = x + y
print(z)

x = "Ana" * 4
print(x)
# Out:
# MomDad
# AnaAnaAnaAna

# %%
# Comparison operators
x = 3
y = 2

t = x > y
print(t)

t = x < y
print(t)

t = x <= y
print(t)

t = x >= y
print(t)

t = x == y
print(t)

t = x != y
print(t)
# Out:
# True
# False
# False
# True
# False
# True

# %%
# Logic
eggs = 2
crit_num = 5
cond = eggs < crit_num

if cond:
  print("Buy eggs!!!")
else:
  print("You have enough eggs")
# Out:
# Buy eggs!!!

# %%
from string import digits
# Input
eggsStr = input()
print(eggsStr)
print(type(eggsStr))

# type casting

eggs = int(eggsStr)
print(eggs)
print(type(eggs))

print(type(10.))
print(type(10))

crit_num = 5
cond = eggs < crit_num

if cond:
  print("Buy eggs!!!")
else:
  print("You have enough eggs")


n = input()
print(n)
# Given a number n from an input in binary, I want you to convert to the decimal representation.


### Conversion from binary to decimal

#  1010 -> 10
#  101 -> 5
#  111 -> 7
#  1111 -> 15
#a_1 a_2 ... a_n
#n= a_n + a_{n-1} * 2 + a_{n-2} * 4 + a_{n-3} * 8 +... a_1 * 2^{n-1}

#  0) Compute the last digit of a number from an input (123 -> 3, 12345 -> 5)
#  0.1) Compute the number without a last digit (123 -> 12, 12345 -> 1234)
#  0.2) Compute a number of digits in a number
#  1) Given a binary number n from an input, print its decimal  represetnation
#  2) Given a number n from an input, print its binary represetnation

#  10 -> 1010
#  5 -> 101
#  7 -> 111
#  15 -> 1111
# Out:
# 4
# 4
# <class 'str'>
# 4
# <class 'int'>
# <class 'float'>
# <class 'int'>
# Buy eggs!!!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-7180f25c2e02> in <cell line: 25>()
#      23
#      24
# ---> 25 n = input()
#      26 print(n)
#      27 ### Conversion from binary to decimal
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
# ...

# %%
cond = True
while cond:
  if 5> 3:
    cond = True
  else:
    cond = True
  print("HELLO")
  #eggsStr = input()
  #eggs = int(eggsStr)

  #crit_num = 5
  #cond = eggs < crit_num

  #if cond:
  #  print("Buy eggs!!!")
  #else:
  #  print("You have enough eggs")
# Out:
# Streaming output truncated to the last 5000 lines.
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# ...

# %%
# For loop
sum = 0
# sum of numbers from 1 to 4.
# n
# We want to compute a sum of numbers from 1 to n where
for i in range(1, 5):
  sum += i

print(sum)
# Out:
# 10

# %%
#

def speed(dist, time):
  print(type(dist), type(time))

  v = dist / time
  time = 0
  # speed = v
  return v

def acceleration(deltaVelocity, time):
  a = deltaVelocity / time
  return a

def surfaceSquare(side):
  surf = side ** 2
  return surf

def surfaceRect(length, width):
  surf = length * width
  return surf

dist = 5
time = 2
MySpeed = speed(dist, time)
print(time)
print(MySpeed)
a = 2.
b = 3.
print(speed(a, b))
#MyAcc = acceleration(10, 2)
#print(MyAcc)
#surf = surfaceSquare(5)
#print(surf)
#surf = surfaceRect(10 ,2)
#print(surf)


#def sum(num):
#  sum = 0
#  for i in range(1, num + 1):
#    sum += i

# return sum

# Not enforced, just info
#def sumTyped(num: int)->int:
#  sum = 0
#  for i in range(1, num + 1):
#    sum += i

#  return sum

#sum3 = sum(3)
#print(sum3)
#print(sumTyped(3))
#print(sumTyped(3.0))
# Out:
# <class 'int'> <class 'int'>
# 2
# 2.5
# <class 'float'> <class 'float'>
# 0.6666666666666666
